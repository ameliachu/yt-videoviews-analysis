# %%
# !pip install apiclient
# Out:
# ...
#   Running setup.py bdist_wheel for apiclient ... done
#   Stored in directory: /Users/chuamelia/Library/Caches/pip/wheels/cc/7a/2d/1b55fbcfe08f95cec4bbef4c6626b79a11be7dc1a5124ddcf7
# Successfully built apiclient
# ...
# You are using pip version 18.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# https://medium.com/greyatom/youtube-data-in-python-6147160c5833

# %%
# !pip install --upgrade google-api-python-client
# Out:
# ...
#     100% |████████████████████████████████| 143kB 3.4MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 102kB 4.2MB/s a 0:00:011
# ...
#     100% |████████████████████████████████| 81kB 4.6MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 133kB 5.9MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for google-api-python-client ... done
#   Stored in directory: /Users/chuamelia/Library/Caches/pip/wheels/b8/f6/f5/b7bef1a5bc0e07ca4aa54c596b0b574c5afc07a9fddccf08f8
# Successfully built google-api-python-client
# pyasn1-modules 0.2.7 has requirement pyasn1<0.5.0,>=0.4.6, but you'll have pyasn1 0.4.3 which is incompatible.
# ...
# You are using pip version 18.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install oauth2client
# Out:
# ...
#     100% |████████████████████████████████| 102kB 5.3MB/s a 0:00:011
# ...
# You are using pip version 18.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
import pprint 
import matplotlib.pyplot as pd

DEVELOPER_KEY = "AIzaSyCwdRZzb55_b5xl2sLhBjaRxrXD3zP4yAo"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
import json

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
q, max_results=50,order="relevance", token=None, location=None, location_radius=None

# %%
results = youtube.search().list(
    q="bestdressed",
    type="video",
    pageToken=None,
    order = "relevance",
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=50,
    location=None,
    locationRadius=None).execute()

# %%
results.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %%
# hour of publish
# Title
# emoji presence 
# talent presence
# if channelname > 10 videos w/ 1 million views 'talent channel
# hashtags used
# description, title, channelTitle, liveBroadcastContent
# collaboration (?)
# tags -> find tags that appear frequently 5-10
# 'commentCount': '6126',
#    'dislikeCount': '296',
#    'favoriteCount': '0',
#    'likeCount': '80601',
#   'viewCount': '664496'}}
# Time since last post
# Day of Week
# length of title

# %%
r = results

# %%
data = pd.from_dict(r)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-00f95be906de> in <module>()
# ----> 1 data = pd.from_dict(r)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'from_dict'

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-6137cde4893c> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
results
# Out:
# {'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/96SSG_Ndg_LEDdzQtfFX1LcpwYg"',
#  'items': [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/W12r8JcXgqCXAOwTGRG1-1AtOks"',
#    'id': {'kind': 'youtube#video', 'videoId': '0nFRKNt0-WI'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCnQhwPVwcP-DnbUZtIMrupw',
#     'channelTitle': 'bestdressed',
#     'description': 'instagram ➭ @best.dressed subscribe for weekly vids ➭ http://bit.ly/bestdressedfam OUTFIT LINKED BELOW ⇩⇩⇩ ✨my jewelry collection ...',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-10-10T16:56:07.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/0nFRKNt0-WI/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/0nFRKNt0-WI/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/0nFRKNt0-WI/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
youtube.videos().list(
                part='statistics, snippet',
                id='KA0nGrdrG5A').execute()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-59-739836f98c97> in <module>()
#       1 youtube.videos().list(
#       2                 part='statistics, snippet',
# ----> 3                 id='KA0nGrdrG5A').execute()
#
# ~/anaconda/envs/py35/lib/python3.6/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131         return positional_wrapper
#     132
#
# ~/anaconda/envs/py35/lib/python3.6/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     849     resp, content = _retry_request(
#     850           http, num_retries, 'request', self._sleep, self._rand, str(self.uri),
# ...
