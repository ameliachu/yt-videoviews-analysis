# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
import pprint 
import matplotlib.pyplot as plt

DEVELOPER_KEY = "AIzaSyCwdRZzb55_b5xl2sLhBjaRxrXD3zP4yAo"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey = DEVELOPER_KEY)

# %%
results = youtube.search().list(
    q="buzzfeed",
    type="video",
    pageToken=None,
    order = "relevance",
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=50,
    location=None,
    locationRadius=None).execute()

# %%
results
# Out:
# {'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/RdkU07dH-ns5Rgag8uyCQC-A278"',
#  'items': [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/5xKtG7O2a4cR8eZjSuMSSFFftLA"',
#    'id': {'kind': 'youtube#video', 'videoId': 'w3XS900kg1U'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCpko_-a4wgz2u_DgDgd9fqA',
#     'channelTitle': 'BuzzFeedVideo',
#     'description': 'The first in a three-episode series in Taiwan! Credits: https://www.buzzfeed.com/bfmp/videos/87992 Check out more awesome videos at BuzzFeedVideo!',
#     'liveBroadcastContent': 'none',
#     'publishedAt': '2019-10-13T15:00:16.000Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/w3XS900kg1U/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/w3XS900kg1U/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/w3XS900kg1U/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
[i for i in results['items']]
# Out:
# [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/_A8r_xULQCSHbspOHr-1KyS16TM"',
#   'id': {'kind': 'youtube#video', 'videoId': 'UV2SEStPg64'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCKijjvu6bN1c-ZHVwR7-5WA',
#    'channelTitle': 'BuzzFeed Unsolved Network',
#    'description': "We're so excited to feature the amazing Reed from Santa Fe, New Mexico this week on a special episode of post mortem! Let us know in the comments if you're ...",
#    'liveBroadcastContent': 'none',
#    'publishedAt': '2019-10-09T22:19:04.000Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/UV2SEStPg64/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/UV2SEStPg64/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/UV2SEStPg64/mqdefault.jpg',
#      'width': 320}},
#    'title': 'USS Yorktown - Q+A feat. Special Guest Reed'}},
# ...

# %%
bd = youtube.videos().list(part='statistics, snippet', id='KA0nGrdrG5A').execute()
# buzzfeed
# Buzzfeed celeb
# mtv news

# %%
bd
snippet
channelId
channelTitle
catagoryId
description > # links in description
liveBroadcastContent
title > title len
publishedAt > dow, hour is the , time since last video
tags

statistics': {'commentCount': '6126',
    'dislikeCount': '296',
    'favoriteCount': '0',
    'likeCount': '80601',
    'viewCount'
# Out:
# {'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/fOOV2RJoFOiYRuPmwisXzTnjkP0"',
#  'items': [{'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/vpKZSIPx9yjF1pNFJWWRPAF2uK0"',
#    'id': 'KA0nGrdrG5A',
#    'kind': 'youtube#video',
#    'snippet': {'categoryId': '26',
#     'channelId': 'UCnQhwPVwcP-DnbUZtIMrupw',
#     'channelTitle': 'bestdressed',
#     'defaultAudioLanguage': 'en',
#     'defaultLanguage': 'en',
# ...

# %%
bd['items'][0]['snippet']['tags']
# Out:
# ['post grad',
#  'post grad life',
#  'existential crisis',
#  'best dressed vlog',
#  'best mess',
#  'post grad depression',
#  'life after college',
#  'graduating college',
#  'post grad plans',
#  'best dressed',
#  'quarter life crisis',
#  'mid life crisis',
#  'life crisis',
#  'workaholic',
#  'consumerism',
#  'my truth',
#  'existenial',
#  'ucla',
#  'best dressed college',
#  'best dressed ucla',
#  'my college experience',
#  'graduating early',
#  'graduating in 3 years',
#  'adulting',
#  'becoming an adult',
#  'trying to adult',
#  'college graduate']

# %%
bd['items'][0]['statistics']
# Out:
# {'commentCount': '6126',
#  'dislikeCount': '296',
#  'favoriteCount': '0',
#  'likeCount': '80601',
#  'viewCount': '664510'}

# %%
bd['items'][0]['snippet']['title']
# Out:
# 'a big fat post-grad existential crisis™'

# %%
bd['items'][0]['snippet']['publishedAt']
# Out:
# '2019-05-30T16:00:04.000Z'

# %%
https://www.googleapis.com/youtube/v3/channels?id=CHANNEL_ID&key=API_KEY&part=contentDetails

# %%
results = youtube.search().list(
    q="buzzfeed unsolved",
    type="video",
    pageToken=None,
    order = "relevance",
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=50,
    location=None,
    locationRadius=None).execute()
UCpko_-a4wgz2u_DgDgd9fqA

# %%
CHANNEL_ID = 'UCpko_-a4wgz2u_DgDgd9fqA'
# https://stackoverflow.com/questions/50199490/youtube-api-v3-get-every-video-id-from-given-channel
results = youtube.channels().list(
    id=CHANNEL_ID,
    pageToken=None,
    part="contentDetails", # Part signifies the different types of data you want 
    maxResults=50).execute()
uploads_playlist_id = results['items'][0]['contentDetails']['relatedPlaylists']['uploads']
# 'UUpko_-a4wgz2u_DgDgd9fqA'

# %%
uploads_playlist_id = 'UUpko_-a4wgz2u_DgDgd9fqA'

# %%
# https://www.googleapis.com/youtube/v3/playlistItems?
# playlistId=UPLOAD_ID&key=API_KEY&part=snippet&maxResults=50 

playlistItemsTokenGetting = youtube.playlistItems().list(
    playlistId=uploads_playlist_id,
    pageToken=None,
    part="snippet", # Part signifies the different types of data you want 
    maxResults=50).execute()

# %%
playlist_items = playlistItemsTokenGetting['items']
num_items = len(playlist_items)
videos_in_playlist = [playlist_items[i]['snippet']['resourceId']['videoId'] for i in range(num_items)]
len(videos_in_playlist )
# Out:
# 50

# %%
nextPageToken = playlistItemsTokenGetting['nextPageToken']
print(nextPageToken)
# Out:
# CDIQAA

# %%
print(videos_in_playlist )
# Out:
# ['tQh8umgs1CE', 'AH3SEqolT8w', '6K9a9aEnSz0', 'L6kkLtuh3mg', 'I8CU8LvG8Oc', 'Y3dLdVW3G-c', 'O7eoDLQjeec', 'w3XS900kg1U', '96rwE1Cm5jI', 'FAP0WqME1wA', 'x0xy-fFc9gI', 'wJ0JMO0aqKo', 'gOgfdAZq9rc', '8i1YKnlUinQ', 'gfmct5GYWDs', 'efLM7vtpVV4', '8ZHR_Je4LGw', 'oLupbovXRy0', 'oUrqvpLt1tc', 'CLBZfGq_row', 'IfwmK-Vgsj4', 'FECksbiG300', 'rer599cmY7o', '0flvNcwI0_o', 'cm1kPvqY_Hs', 'zY6X20D1Zj8', 'KEmd6GyTzho', 'JNJcIjef-ps', 'NLQ4VMSY3HA', 'wKd8XrhXPzg', '4p_zr4NdVyE', '3p84dHyitfM', 'jn3NKJU17xE', '4t0qlbeABYY', 'nWPRU9XOBJY', 'wA05YHM8qaw', 'bdDGBWi1AFc', '1lCjzF1g-wk', '9mRHHo4kYJk', '8FVD8wT9mvc', 'IDsy02zcljg', '7QM5TKW5a3U', '46UNNXlGKsY', 'N4UJxrgEZ5I', 'TWJXMgzeWaY', 'pIuCqUnvHdk', '7JrD0STn9o8', 'ylZz7R7aNuw', '8Ipo6GYQpfs', 'sU07ZanA5FQ']

# %%
df = pd.DataFrame(data, columns =['Name', 'Age', 'Score'])
